# %% [markdown]
# `pd.json_normalize` is a very useful way to unnest/ explode data structure that is commonly seen in JSON files.
# As long as the data/ a column with a dataframe contains a `dict`, we can use this method on it:

# %%
import pandas as pd 
from IPython.display import display

data = {
    'name': 'team 1', 
    'scores': [10, 15, 220], 
}
display(pd.DataFrame(data).head())

print(f'score is type of {type(data["scores"])}')

pd.json_normalize(data=data, 
                  record_path='scores', 
                  record_prefix='scores.',
                  meta=['name'])
# Out:
#      name  scores
# 0  team 1      10
# 1  team 1      15
# 2  team 1     220
# score is type of <class 'list'>
#    scores.0    name
# 0        10  team 1
# 1        15  team 1
# 2       220  team 1

# %%
# use it on dict()
data = {
    'name': 'team 1', 
    'scores': [10, 15, 220], 
    'members': [
        {'name': 'Tom', 'skill_level': 10}, 
        {'name': 'Sam', 'skill_level': 8}, 
        {'name': 'Ken', 'skill_level': 6}
    ]
}
display(pd.DataFrame(data).head())

print(f'score is type of {type(data["members"])}')
pd.json_normalize(data=data, 
                  record_path=['members'], 
                  record_prefix='members.', 
                  meta=['name',])
# Out:
#      name  scores                             members
# 0  team 1      10  {'name': 'Tom', 'skill_level': 10}
# 1  team 1      15   {'name': 'Sam', 'skill_level': 8}
# 2  team 1     220   {'name': 'Ken', 'skill_level': 6}
# score is type of <class 'list'>
#   members.name  members.skill_level    name
# 0          Tom                   10  team 1
# 1          Sam                    8  team 1
# 2          Ken                    6  team 1

# %%
# even on more complex datatypes 
complex_data = [
    {
        "state": "Florida",
        "shortname": "FL",
        "info": {"governor": "Rick Scott"},
        "counties": [
            {"name": "Dade", "population": 12345},
            {"name": "Broward", "population": 40000},
            {"name": "Palm Beach", "population": 60000},
        ],
    },
    {
        "state": "Ohio",
        "shortname": "OH",
        "info": {"governor": "John Kasich"},
        "counties": [
            {"name": "Summit", "population": 1234},
            {"name": "Cuyahoga", "population": 1337},
        ],
    },
]

display(pd.DataFrame(complex_data).head())
pd.json_normalize(data=complex_data, 
                  record_path='counties', 
                  meta=['state', 'shortname', ['info', 'governor']])
# Out:
#      state shortname                         info  \
# 0  Florida        FL   {'governor': 'Rick Scott'}
# 1     Ohio        OH  {'governor': 'John Kasich'}
#
#                                             counties
# 0  [{'name': 'Dade', 'population': 12345}, {'name...
# 1  [{'name': 'Summit', 'population': 1234}, {'nam...
#          name  population    state shortname info.governor
# 0        Dade       12345  Florida        FL    Rick Scott
# 1     Broward       40000  Florida        FL    Rick Scott
# 2  Palm Beach       60000  Florida        FL    Rick Scott
# 3      Summit        1234     Ohio        OH   John Kasich
# 4    Cuyahoga        1337     Ohio        OH   John Kasich

# %%
# However, we can see that a more even complex type of JSON files, 
# would eventually fails, 
# At the same time, hardcoding each columns for extract become more 
# cumbersome
even_more_complex_data = [
    {
        "city": "Greatpole",
        "info": {"ruler": "Tommy the Great"},
        "number": 20, 
        "towns": [
            {"name": "Small Villa",
             "streets": [{"name": "street-1"}]},
            {"name": "Mid Villa",
             "streets": [{"name": "street-2"}]},
            {"name": "Large Villa",
             "streets": [{"name": "street-3"}]},
        ],
        "population": [
            {'year': '2022', 'size': 2000}, 
            {'year': '2021', 'size': 1000}
        ],
    }
]

display(pd.DataFrame(even_more_complex_data).head())
pd.json_normalize(data=even_more_complex_data, 
                  record_path=['towns'], 
                  record_prefix='towns.', 
                  meta=['city', ['info', 'ruler']])
# Out:
#         city                          info  number  \
# 0  Greatpole  {'ruler': 'Tommy the Great'}      20
#
#                                                towns  \
# 0  [{'name': 'Small Villa', 'streets': [{'name': ...
#
#                                           population
# 0  [{'year': '2022', 'size': 2000}, {'year': '202...
#     towns.name           towns.streets       city       info.ruler
# 0  Small Villa  [{'name': 'street-1'}]  Greatpole  Tommy the Great
# 1    Mid Villa  [{'name': 'street-2'}]  Greatpole  Tommy the Great
# 2  Large Villa  [{'name': 'street-3'}]  Greatpole  Tommy the Great

# %% [markdown]
# ## Generalise approach
#
# 1. scan all the columns, explode columns first

# %%
from collections import namedtuple
from functools import reduce
import numpy as np

ColumnDtype = namedtuple('ColumnDtype', 'column dtype')

### Single step include all these functions
def get_dtypes(dataframe) -> tuple[str, type]:
    """Infer the dtypes of each column"""
    infer_row = dataframe.head(1)
    return [ColumnDtype(col, type(infer_row[col][0])) for col in infer_row]    


def select_inferred_dtypes(dataframe: pd.DataFrame, include: list=None):
    inferred_dtypes = get_dtypes(dataframe)
    
    if include:
        inferred_dtypes = filter(lambda info: info.dtype in include, inferred_dtypes)
        
    return list(map(lambda info: info.column, inferred_dtypes))


def explode_columns(dataframe: pd.DataFrame):
    """Explode array type columns iteratively"""
    dataframe = dataframe.copy()
    array_columns = select_inferred_dtypes(dataframe, include=[list, np.array])
    df = reduce(lambda df, col: df.explode(col), array_columns, dataframe)
    return df.reset_index(drop=True)


def normalise_json_columns(dataframe: pd.DataFrame):
    """Normalise (unnest) dict columns iteratively"""
    df = dataframe.copy()
    
    dict_columns = select_inferred_dtypes(df, include=[dict])
    
    for norm_col in dict_columns:
        all_columns = df.columns.tolist()   
        all_columns.remove(norm_col)
        
        norm_df = pd.json_normalize(df[norm_col])
        norm_df = norm_df.rename(columns={col: f'{norm_col}.{col}' for col in norm_df.columns})
        df = pd.concat([df[all_columns], norm_df], axis=1)
    return df

# %%
# test for 1 iteration 
df = pd.DataFrame(even_more_complex_data)
df = explode_columns(df)
normalise_json_columns(df)
# Out:
#         city  number       info.ruler   towns.name           towns.streets  \
# 0  Greatpole      20  Tommy the Great  Small Villa  [{'name': 'street-1'}]
# 1  Greatpole      20  Tommy the Great  Small Villa  [{'name': 'street-1'}]
# 2  Greatpole      20  Tommy the Great    Mid Villa  [{'name': 'street-2'}]
# 3  Greatpole      20  Tommy the Great    Mid Villa  [{'name': 'street-2'}]
# 4  Greatpole      20  Tommy the Great  Large Villa  [{'name': 'street-3'}]
# 5  Greatpole      20  Tommy the Great  Large Villa  [{'name': 'street-3'}]
#
#   population.year  population.size
# 0            2022             2000
# 1            2021             1000
# 2            2022             2000
# 3            2021             1000
# 4            2022             2000
# 5            2021             1000

# %%
def normalise_json_dataframe(dataframe: pd.DataFrame):
    df = dataframe.copy()
    
    while True:
        df = explode_columns(df)
        df = normalise_json_columns(df)
        
        if not select_inferred_dtypes(df, include=[list, dict]): 
            break 
        
    return df

# %%
df = pd.DataFrame(even_more_complex_data)
normalise_json_dataframe(df)
# Out:
#         city  number       info.ruler   towns.name population.year  \
# 0  Greatpole      20  Tommy the Great  Small Villa            2022
# 1  Greatpole      20  Tommy the Great  Small Villa            2021
# 2  Greatpole      20  Tommy the Great    Mid Villa            2022
# 3  Greatpole      20  Tommy the Great    Mid Villa            2021
# 4  Greatpole      20  Tommy the Great  Large Villa            2022
# 5  Greatpole      20  Tommy the Great  Large Villa            2021
#
#    population.size towns.streets.name
# 0             2000           street-1
# 1             1000           street-1
# 2             2000           street-2
# 3             1000           street-2
# 4             2000           street-3
# 5             1000           street-3

# %%
data = {'posJournal': {'transmissionHeader': {'organizatonID': 'BP', 'storeLocationID': '0E05C', 'country': 'AU', 'origin': 'BP', 'resend': False, 'connectorType': 'ESO'}, 'journalReport': {'journalHeader': {'beginDate': '2021-12-08', 'beginTime': '11:19:00', 'endDate': '2021-12-08', 'endTime': '11:19:00'}, 'journalEvents': [{'saleEvent': {'cashierID': '1000170', 'registerID': '1', 'eventSequenceID': 25, 'transactionID': '70001', 'eventStartDate': '2021-12-08', 'eventStartTime': '11:19:00', 'eventEndDate': '2021-12-08', 'eventEndTime': '11:19:00', 'businessDate': '2021-12-08', 'uuid': '10019202021120870001180001', 'resend': False, 'transformTimestamp': '2021-12-08T00:27:26Z', 'transactionDetailGroup': [{'itemLine': {'itemCode': {'inventoryItemID': '1000116', 'sellingItemID': '1000197', 'posCode': '9311008005302', 'posCodeModifier': {'value': '0'}}, 'description': 'PAT_4N20 TRAVELLER PIE BEEF CH BAC_160G, Each', 'actualSalesPrice': {'value': '4.50000', 'currency': 'AUD'}}, 'regularSellPrice': {'value': '4.50000', 'currency': 'AUD'}, 'sellingUnits': {'value': '1.00000', 'uom': 'EA'}, 'salesQuantity': {'value': '5.00000', 'uom': 'EA'}, 'salesAmount': {'value': '22.50000', 'currency': 'AUD'}, 'itemTypeCode': 'mdse', 'itemTaxes': [{'taxableSalesAmount': {'value': '20.45000', 'currency': 'AUD'}, 'taxCollectedAmount': {'value': '2.05000', 'currency': 'AUD'}}], 'discounts': [{'discountID': '', 'discountReason': 'loyaltyDiscount', 'discountAmount': {'value': '0', 'currency': 'AUD'}, 'discountQuantity': {'value': '0', 'uom': 'EA'}}], 'promotions': [{'promotionID': '1298437', 'promotionAmount': {'value': '0', 'currency': 'AUD'}, 'promotionQuantity': {'value': '0', 'uom': 'EA'}}], 'transactionLineStatus': {'status': 'normal'}, 'transactionLineSequenceNumber': 1}, {'tenderInfo': {'tender': {'tenderName': 'Bank Debit', 'tenderID': '9', 'tenderCode': 'fleetCards'}, 'tenderAmount': {'value': '1.55000'}, 'changeFlag': False}}, {'tenderInfo': {'tender': {'tenderName': 'Cash', 'tenderID': '1', 'tenderCode': 'cash', 'tenderSubCode': 'cash'}, 'tenderAmount': {'value': '50.00000'}, 'changeFlag': False}}, {'tenderInfo': {'tender': {'tenderName': 'Cash', 'tenderID': '1', 'tenderCode': 'cash', 'tenderSubCode': 'cash'}, 'tenderAmount': {'value': '-29.05000'}, 'changeFlag': True}}], 'transactionSummary': {'transactionTotalNetAmount': {'value': '20.45000'}, 'transactionTotalTaxNetAmount': {'value': '2.05000'}, 'transactionTotalGrandAmount': {'value': '22.50000'}}}}]}}}
df = pd.DataFrame([data])
df = normalise_json_dataframe(df)


def make_simplify_names(dataframe: pd.DataFrame):
    rename_maps = {
        col: col.replace('posJournal.transmissionHeader.', '') for col in dataframe.columns
    }
    dataframe = dataframe.rename(columns=rename_maps)

    rename_maps = {
        col: col.replace('posJournal.journalReport.journalEvents.', '') for col in dataframe.columns
    }
    dataframe = dataframe.rename(columns=rename_maps)

    return dataframe

df = make_simplify_names(df)
df
# Out:
#   organizatonID storeLocationID country origin  resend connectorType  \
# 0            BP           0E05C      AU     BP   False           ESO
# 1            BP           0E05C      AU     BP   False           ESO
# 2            BP           0E05C      AU     BP   False           ESO
# 3            BP           0E05C      AU     BP   False           ESO
#
#   posJournal.journalReport.journalHeader.beginDate  \
# 0                                       2021-12-08
# 1                                       2021-12-08
# 2                                       2021-12-08
# 3                                       2021-12-08
#
#   posJournal.journalReport.journalHeader.beginTime  \
# 0                                         11:19:00
# 1                                         11:19:00
# 2                                         11:19:00
# 3                                         11:19:00
#
#   posJournal.journalReport.journalHeader.endDate  \
# 0                                     2021-12-08
# 1                                     2021-12-08
# 2                                     2021-12-08
# 3                                     2021-12-08
#
#   posJournal.journalReport.journalHeader.endTime  ...  \
# 0                                       11:19:00  ...
# 1                                       11:19:00  ...
# 2                                       11:19:00  ...
# 3                                       11:19:00  ...
#
#   saleEvent.transactionDetailGroup.discounts.discountReason  \
# 0                                    loyaltyDiscount
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#   saleEvent.transactionDetailGroup.discounts.discountAmount.value  \
# 0                                                  0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#    saleEvent.transactionDetailGroup.discounts.discountAmount.currency  \
# 0                                                AUD
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#   saleEvent.transactionDetailGroup.discounts.discountQuantity.value  \
# 0                                                  0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#   saleEvent.transactionDetailGroup.discounts.discountQuantity.uom  \
# 0                                                 EA
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#   saleEvent.transactionDetailGroup.promotions.promotionID  \
# 0                                            1298437
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#   saleEvent.transactionDetailGroup.promotions.promotionAmount.value  \
# 0                                                  0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#   saleEvent.transactionDetailGroup.promotions.promotionAmount.currency  \
# 0                                                AUD
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#   saleEvent.transactionDetailGroup.promotions.promotionQuantity.value  \
# 0                                                  0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
#   saleEvent.transactionDetailGroup.promotions.promotionQuantity.uom
# 0                                                 EA
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
#
# [4 rows x 64 columns]
